# %%
import pandas as pd 
import matplotlib.pyplot as plt
import folium

# %%
df = pd.read_csv("../local-data/requested-data/raw.csv")
dallas_df = df[(df['COUNTY_CODE'] == 57)]
dallas_df.columns = dallas_df.columns.str.upper().str.replace(' ', '_')
display(dallas_df.columns)
display(len(dallas_df))
display(dallas_df.head(100))
# Out:
# Index(['BOARD_CDE', 'BOARD_NAME', 'LICENSE_TYPE_CDE', 'LICENSE_TYPE',
#        'FILE_NBR', 'LICENSE_NUMBER', 'EXPIRES_DATE', 'STATUS_DATE',
#        'LIC_STATUS', 'ORIG_DATE', 'MODIFIERS', 'RANK_CDE', 'RANK_DESC',
#        'RANK_DATE', 'XENT_ID', 'PRIMARY_NAME', 'DBA_NAME', 'ALT_KEYS',
#        'CI_KEYNAME', 'ADDRESS_TYPE', 'ADDR_NAME', 'ADDRESS', 'CITY', 'STATE',
#        'ZIP', 'PHNE_NBR', 'COUNTY_CODE', 'COUNTY_NAME', 'MAIL_NAME',
#        'MAIL_ADDRESS', 'MAIL_CITY', 'MAIL_STATE', 'MAIL_ZIP',
#        'MAIL_COUNTY_CODE', 'MAIL_COUNTY_NAME', 'MAIL_PHNE_NBR', 'E_MAIL_ADDR',
#        'RSP_PERS_ONSITE'],
#       dtype='object')
# 12
#        BOARD_CDE            BOARD_NAME  LICENSE_TYPE_CDE        LICENSE_TYPE  \
# 4246        1523  Retail Foods Program              2301  Food Establishment
# 6394        1523  Retail Foods Program              2301  Food Establishment
# 7237        1523  Retail Foods Program              2301  Food Establishment
# ...
