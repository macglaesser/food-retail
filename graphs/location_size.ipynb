# %%
import pandas as pd

# %%
df = pd.read_csv('../local-data/property_size_merged.csv')
df.head()
# Out:
#    ZIP_CODE  COUNTY             Y         STORE_TYPE     CITY          Ï»¿X  \
# 0     75043  DALLAS  3.874255e+06  Convenience Store  GARLAND -1.075289e+07
# 1     75237  DALLAS  3.849507e+06  Convenience Store   DALLAS -1.078522e+07
# 2     75208  DALLAS  3.860979e+06  Convenience Store   DALLAS -1.078202e+07
# 3     75227  DALLAS  3.867771e+06        Supermarket   DALLAS -1.076301e+07
# 4     75228  DALLAS  3.873357e+06  Convenience Store   DALLAS -1.076160e+07
#
#     LATITUDE ADDITONAL_ADDRESS INCENTIVE_PROGRAM  GRANTEE_NAME  ...  \
# 0  32.841278               NaN               NaN           NaN  ...
# 1  32.654293               NaN               NaN           NaN  ...
# 2  32.741020               NaN               NaN           NaN  ...
# 3  32.792328               NaN               NaN           NaN  ...
# 4  32.834496               NaN               NaN           NaN  ...
#
#                           LEGAL2 LEGAL3                            LEGAL4  \
# ...
