# %%
import pandas as pd
import folium

# %%
merged = pd.read_csv("../local-data/snap_sales_tax_merged_data.csv")

# %%
active_map = folium.Map(location=[32.7767, -96.7970], zoom_start=10)
store_types = merged['STORE_TYPE'].unique()

store_type_colors = {
    'Convenience Store': 'red',
    'Discount Retail': 'darkblue',
    'Pharmacy': 'lightgreen',
    'Supermarket': 'blue',
    'Other': 'green',
    'Grocery Store': 'purple',
    'Super Store': 'orange',
    'Farmers and Markets': 'gray',
    'Specialty Store': 'pink',
    'Liquor Store': 'darkred',        
    'Confectionery': 'purple',        
    'Food Store': 'darkgreen',        
    'Produce Market': 'lightgreen',   
    'Seafood Market': 'cadetblue',    
    'Meat Market': 'darkred',
    'Bakery': 'lightblue',         
    'Specialty Food': 'darkgreen'
}

feature_groups = {}
for store_type in store_types:
    feature_groups[store_type] = folium.FeatureGroup(name=store_type)

for idx, row in merged.iterrows():
    if pd.notna(row['LATITUDE']) and pd.notna(row['LONGITUDE']):  # Use uppercase
        store_type = row['STORE_TYPE']
        popup_text = f"<b>{row['STORE_NAME']}</b><br>Type: {store_type}"
        
        folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],  # Use uppercase
            popup=folium.Popup(popup_text, max_width=300),
            icon=folium.Icon(color=store_type_colors[store_type], icon='info-sign')
        ).add_to(feature_groups[store_type])

for fg in feature_groups.values():
    fg.add_to(active_map)

folium.LayerControl().add_to(active_map)

active_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5cc0a4fa9441682430d4ad215ac7c3bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5cc0a4fa9441682430d4ad215ac7c3bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5cc0a4fa9441682430d4ad215ac7c3bf = L.map(
#                 &quot;map_5cc0a4fa9441682430d4ad215ac7c3bf&quot;,
#                 {
#                     center: [32.7767, -96.797],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_995ad9e36125097c16def054616af3a0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_995ad9e36125097c16def054616af3a0.addTo(map_5cc0a4fa9441682430d4ad215ac7c3bf);
#
#
#             var feature_group_cb439cab1164742025663fa9812781a8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_baafaeb2db277466b4cb4aa426029e30 = L.marker(
#                 [32.841278, -96.594841],
#                 {
# }
#             ).addTo(feature_group_cb439cab1164742025663fa9812781a8);
#
#
#             var icon_02a1451dce2c4510cc280f82bd0b5e66 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c7a28d98f7c2691508c546f7458d6de8 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_4850b6b971a88b6a15b625267d0fa2d2 = $(`&lt;div id=&quot;html_4850b6b971a88b6a15b625267d0fa2d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;7-eleven Convenience Store 32914B&lt;/b&gt;&lt;br&gt;Type: Convenience Store&lt;/div&gt;`)[0];
#                 popup_c7a28d98f7c2691508c546f7458d6de8.setContent(html_4850b6b971a88b6a15b625267d0fa2d2);
#
#
#
#         marker_baafaeb2db277466b4cb4aa426029e30.bindPopup(popup_c7a28d98f7c2691508c546f7458d6de8)
#         ;
#
#
#
#
#                 marker_baafaeb2db277466b4cb4aa426029e30.setIcon(icon_02a1451dce2c4510cc280f82bd0b5e66);
#
#
#             var marker_b6421a535b01f7dae2f53b11af5e17de = L.marker(
#                 [32.654293, -96.885239],
#                 {
# }
#             ).addTo(feature_group_cb439cab1164742025663fa9812781a8);
#
#
#             var icon_3fab086cd1ac444762c5fdeb74c13ec8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0555570fd961a6736e3e385eaf36d5c9 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_a447539c38fa43a29add41e1ab5915c2 = $(`&lt;div id=&quot;html_a447539c38fa43a29add41e1ab5915c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Grand Trip&lt;/b&gt;&lt;br&gt;Type: Convenience Store&lt;/div&gt;`)[0];
#                 popup_0555570fd961a6736e3e385eaf36d5c9.setContent(html_a447539c38fa43a29add41e1ab5915c2);
#
#
#
#         marker_b6421a535b01f7dae2f53b11af5e17de.bindPopup(popup_0555570fd961a6736e3e385eaf36d5c9)
#         ;
#
#
#
#
#                 marker_b6421a535b01f7dae2f53b11af5e17de.setIcon(icon_3fab086cd1ac444762c5fdeb74c13ec8);
#
#
#             var marker_7a2e7dea0a3a2856508214c49b3d5053 = L.marker(
#                 [32.74102, -96.856522],
#                 {
# }
#             ).addTo(feature_group_cb439cab1164742025663fa9812781a8);
#
#
#             var icon_07c5db2721f3b143725a801d966815db = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4220e4349093d00debbc5d7c1b605a12 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_6449e2c4604819d055aabe6595b10af7 = $(`&lt;div id=&quot;html_6449e2c4604819d055aabe6595b10af7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Corner Market&lt;/b&gt;&lt;br&gt;Type: Convenience Store&lt;/div&gt;`)[0];
#                 popup_4220e4349093d00debbc5d7c1b605a12.setContent(html_6449e2c4604819d055aabe6595b10af7);
